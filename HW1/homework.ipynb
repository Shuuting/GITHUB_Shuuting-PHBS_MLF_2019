# %% [markdown]
# # Homework 1: playing with pandas dataframe

# %%
from scipy.io import arff
import pandas as pd

# %%
data = arff.loadarff('4year.arff')
df=pd.DataFrame(data[0])

# %%
df.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5     Attr6     Attr7    Attr8  \
# 0  0.159290  0.46240  0.07773  1.1683  -44.853  0.467020  0.189480  0.82895
# 1 -0.127430  0.46243  0.26917  1.7517    7.597  0.000925 -0.127430  1.16250
# 2  0.070488  0.23570  0.52781  3.2393  125.680  0.163670  0.086895  2.87180
# 3  0.136760  0.40538  0.31543  1.8705   19.115  0.504970  0.136760  1.45390
# 4 -0.110080  0.69793  0.18878  1.2713  -15.344  0.000000 -0.110080  0.43282
#
#     Attr9   Attr10  ...    Attr56   Attr57   Attr58    Attr59   Attr60  \
# 0  1.1223  0.38330  ...  0.108990  0.41557  0.89101  0.001422   7.7928
# 1  1.2944  0.53757  ... -0.089372 -0.23704  1.06250  0.150410   5.4327
# 2  1.0574  0.67689  ...  0.054286  0.10413  0.94571  0.000000   7.1070
# 3  1.1144  0.58938  ...  0.102630  0.23203  0.89737  0.073024   6.1384
# 4  1.7350  0.30207  ...  0.439880 -0.36440  0.57153  0.000000  18.8010
#
#    Attr61   Attr62  Attr63   Attr64  class
# ...

# %%
df['bankruptcy']=(df['class']==b'1')

# %%
df.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5     Attr6     Attr7    Attr8  \
# 0  0.159290  0.46240  0.07773  1.1683  -44.853  0.467020  0.189480  0.82895
# 1 -0.127430  0.46243  0.26917  1.7517    7.597  0.000925 -0.127430  1.16250
# 2  0.070488  0.23570  0.52781  3.2393  125.680  0.163670  0.086895  2.87180
# 3  0.136760  0.40538  0.31543  1.8705   19.115  0.504970  0.136760  1.45390
# 4 -0.110080  0.69793  0.18878  1.2713  -15.344  0.000000 -0.110080  0.43282
#
#     Attr9   Attr10  ...   Attr57   Attr58    Attr59   Attr60  Attr61   Attr62  \
# 0  1.1223  0.38330  ...  0.41557  0.89101  0.001422   7.7928  4.9914  119.810
# 1  1.2944  0.53757  ... -0.23704  1.06250  0.150410   5.4327  3.4629  100.970
# 2  1.0574  0.67689  ...  0.10413  0.94571  0.000000   7.1070  3.3808   76.076
# 3  1.1144  0.58938  ...  0.23203  0.89737  0.073024   6.1384  4.2241   88.299
# 4  1.7350  0.30207  ... -0.36440  0.57153  0.000000  18.8010  2.7925  146.390
#
#    Attr63   Attr64  class  bankruptcy
# ...

# %%
df.describe()
# Out:
#              Attr1        Attr2        Attr3         Attr4         Attr5  \
# count  9791.000000  9791.000000  9791.000000   9749.000000  9.771000e+03
# mean      0.043019     0.596404     0.130959      8.136600  6.465164e+01
# std       0.359321     4.587122     4.559074    290.647281  1.475939e+04
# min     -12.458000     0.000000  -445.910000     -0.045319 -3.794600e+05
# 25%       0.001321     0.263145     0.020377      1.047000 -5.121700e+01
# 50%       0.041364     0.467740     0.199290      1.591800 -5.557600e-02
# 75%       0.111130     0.689255     0.410670      2.880400  5.573200e+01
# max      20.482000   446.910000    22.769000  27146.000000  1.034100e+06
#
#              Attr6        Attr7         Attr8        Attr9       Attr10  ...  \
# count  9791.000000  9791.000000   9773.000000  9792.000000  9791.000000  ...
# mean     -0.059273     0.059446     19.884016     1.882296     0.389040  ...
# std       6.812754     0.533344    698.697015    17.674650     4.590299  ...
# ...

# %%
sum(df.bankruptcy==True)
# Out:
# 515

# %%
df.head()
# Out:
#       Attr1    Attr2    Attr3   Attr4    Attr5     Attr6     Attr7    Attr8  \
# 0  0.159290  0.46240  0.07773  1.1683  -44.853  0.467020  0.189480  0.82895
# 1 -0.127430  0.46243  0.26917  1.7517    7.597  0.000925 -0.127430  1.16250
# 2  0.070488  0.23570  0.52781  3.2393  125.680  0.163670  0.086895  2.87180
# 3  0.136760  0.40538  0.31543  1.8705   19.115  0.504970  0.136760  1.45390
# 4 -0.110080  0.69793  0.18878  1.2713  -15.344  0.000000 -0.110080  0.43282
#
#     Attr9   Attr10  ...   Attr57   Attr58    Attr59   Attr60  Attr61   Attr62  \
# 0  1.1223  0.38330  ...  0.41557  0.89101  0.001422   7.7928  4.9914  119.810
# 1  1.2944  0.53757  ... -0.23704  1.06250  0.150410   5.4327  3.4629  100.970
# 2  1.0574  0.67689  ...  0.10413  0.94571  0.000000   7.1070  3.3808   76.076
# 3  1.1144  0.58938  ...  0.23203  0.89737  0.073024   6.1384  4.2241   88.299
# 4  1.7350  0.30207  ... -0.36440  0.57153  0.000000  18.8010  2.7925  146.390
#
#    Attr63   Attr64  class  bankruptcy
# ...

# %%
df.columns
# Out:
# Index(['Attr1', 'Attr2', 'Attr3', 'Attr4', 'Attr5', 'Attr6', 'Attr7', 'Attr8',
#        'Attr9', 'Attr10', 'Attr11', 'Attr12', 'Attr13', 'Attr14', 'Attr15',
#        'Attr16', 'Attr17', 'Attr18', 'Attr19', 'Attr20', 'Attr21', 'Attr22',
#        'Attr23', 'Attr24', 'Attr25', 'Attr26', 'Attr27', 'Attr28', 'Attr29',
#        'Attr30', 'Attr31', 'Attr32', 'Attr33', 'Attr34', 'Attr35', 'Attr36',
#        'Attr37', 'Attr38', 'Attr39', 'Attr40', 'Attr41', 'Attr42', 'Attr43',
#        'Attr44', 'Attr45', 'Attr46', 'Attr47', 'Attr48', 'Attr49', 'Attr50',
#        'Attr51', 'Attr52', 'Attr53', 'Attr54', 'Attr55', 'Attr56', 'Attr57',
#        'Attr58', 'Attr59', 'Attr60', 'Attr61', 'Attr62', 'Attr63', 'Attr64',
#        'class', 'bankruptcy'],
#       dtype='object')

# %% [markdown]
# # 1.Create a new dataframe

# %%
df2=df.iloc[:,[0,1,6,9,65]]

# %%
df2
# Out:
#          Attr1    Attr2     Attr7   Attr10  bankruptcy
# 0     0.159290  0.46240  0.189480  0.38330       False
# 1    -0.127430  0.46243 -0.127430  0.53757       False
# 2     0.070488  0.23570  0.086895  0.67689       False
# 3     0.136760  0.40538  0.136760  0.58938       False
# 4    -0.110080  0.69793 -0.110080  0.30207       False
# ...        ...      ...       ...      ...         ...
# 9787  0.004676  0.54949  0.013002  0.43205        True
# 9788 -0.027610  0.60748 -0.027610  0.33509        True
# 9789 -0.238290  0.62708 -0.240360  0.17760        True
# 9790  0.097188  0.75300  0.104280  0.24700        True
# 9791  0.021416  0.48678  0.027253  0.51267        True
#
# [9792 rows x 5 columns]

# %%
df3=df.loc[:,['Attr1','Attr2','Attr7','Attr10','bankruptcy']]

# %%
df3
# Out:
#          Attr1    Attr2     Attr7   Attr10  bankruptcy
# 0     0.159290  0.46240  0.189480  0.38330       False
# 1    -0.127430  0.46243 -0.127430  0.53757       False
# 2     0.070488  0.23570  0.086895  0.67689       False
# 3     0.136760  0.40538  0.136760  0.58938       False
# 4    -0.110080  0.69793 -0.110080  0.30207       False
# ...        ...      ...       ...      ...         ...
# 9787  0.004676  0.54949  0.013002  0.43205        True
# 9788 -0.027610  0.60748 -0.027610  0.33509        True
# 9789 -0.238290  0.62708 -0.240360  0.17760        True
# 9790  0.097188  0.75300  0.104280  0.24700        True
# 9791  0.021416  0.48678  0.027253  0.51267        True
#
# [9792 rows x 5 columns]

# %%
df2.rename(columns={'Attr1':'X1','Attr2':'X2','Attr7':'X7','Attr10':'X10'})
# Out:
#             X1       X2        X7      X10  bankruptcy
# 0     0.159290  0.46240  0.189480  0.38330       False
# 1    -0.127430  0.46243 -0.127430  0.53757       False
# 2     0.070488  0.23570  0.086895  0.67689       False
# 3     0.136760  0.40538  0.136760  0.58938       False
# 4    -0.110080  0.69793 -0.110080  0.30207       False
# ...        ...      ...       ...      ...         ...
# 9787  0.004676  0.54949  0.013002  0.43205        True
# 9788 -0.027610  0.60748 -0.027610  0.33509        True
# 9789 -0.238290  0.62708 -0.240360  0.17760        True
# 9790  0.097188  0.75300  0.104280  0.24700        True
# 9791  0.021416  0.48678  0.027253  0.51267        True
#
# [9792 rows x 5 columns]

# %% [markdown]
# # 2.Fill-in the missing values

# %%
from sklearn.preprocessing import Imputer

# %%
imr=Imputer(missing_values='na',strategy='mean',axis=0)
# Out:
# C:\Users\zhaoshuting\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:66: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %% [markdown]
# # 3.Find the mean and std

# %%
df2.mean(axis=0)
# Out:
# Attr1         0.043019
# Attr2         0.596404
# Attr7         0.059446
# Attr10        0.389040
# bankruptcy    0.052594
# dtype: float64

# %%
df2.std(axis=0)
# Out:
# Attr1         0.359321
# Attr2         4.587122
# Attr7         0.533344
# Attr10        4.590299
# bankruptcy    0.223233
# dtype: float64

# %%
df2.mean(df2.bankruptcy==True,axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-3c6092440a58> in <module>
# ----> 1 df2.mean(df2.bankruptcy==True,axis=0)
#
# TypeError: stat_func() got multiple values for argument 'axis'
